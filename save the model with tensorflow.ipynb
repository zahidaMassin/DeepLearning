# %% [markdown]
# # Programming Assignment
#
# ## Saving and loading models, with application to the EuroSat dataset
#
# ### Instructions
#
# In this notebook, you will create a neural network that classifies land uses and land covers from satellite imagery. You will save your model using Tensorflow's callbacks and reload it later. You will also load in a pre-trained neural network classifier and compare performance with it.
#
# Some code cells are provided for you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os
import numpy as np
import pandas as pd

# If you would like to make further imports from tensorflow, add them here

# %% [markdown]
# ![EuroSAT overview image](data/eurosat_overview.jpg)
#
# #### The EuroSAT dataset
#
# In this assignment, you will use the [EuroSAT dataset](https://github.com/phelber/EuroSAT). It consists of 27000 labelled Sentinel-2 satellite images of different land uses: residential, industrial, highway, river, forest, pasture, herbaceous vegetation, annual crop, permanent crop and sea/lake. For a reference, see the following papers:
# - Eurosat: A novel dataset and deep learning benchmark for land use and land cover classification. Patrick Helber, Benjamin Bischke, Andreas Dengel, Damian Borth. IEEE Journal of Selected Topics in Applied Earth Observations and Remote Sensing, 2019.
# - Introducing EuroSAT: A Novel Dataset and Deep Learning Benchmark for Land Use and Land Cover Classification. Patrick Helber, Benjamin Bischke, Andreas Dengel. 2018 IEEE International Geoscience and Remote Sensing Symposium, 2018.
#
# Your goal is to construct a neural network that classifies a satellite image into one of these 10 classes, as well as applying some of the saving and loading techniques you have learned in the previous sessions.

# %% [markdown]
# #### Import the data
#
# The dataset you will train your model on is a subset of the total data, with 4000 training images and 1000 testing images, with roughly equal numbers of each class. The code to import the data is provided below.

# %%
# Run this cell to import the Eurosat data

def load_eurosat_data():
    data_dir = 'data/'
    x_train = np.load(os.path.join(data_dir, 'x_train.npy'))
    y_train = np.load(os.path.join(data_dir, 'y_train.npy'))
    x_test  = np.load(os.path.join(data_dir, 'x_test.npy'))
    y_test  = np.load(os.path.join(data_dir, 'y_test.npy'))
    return (x_train, y_train), (x_test, y_test)

(x_train, y_train), (x_test, y_test) = load_eurosat_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# You can now construct a model to fit to the data. Using the Sequential API, build your model according to the following specifications:
#
# * The model should use the input_shape in the function argument to set the input size in the first layer.
# * The first layer should be a Conv2D layer with 16 filters, a 3x3 kernel size, a ReLU activation function and 'SAME' padding. Name this layer 'conv_1'.
# * The second layer should also be a Conv2D layer with 8 filters, a 3x3 kernel size, a ReLU activation function and 'SAME' padding. Name this layer 'conv_2'.
# * The third layer should be a MaxPooling2D layer with a pooling window size of 8x8. Name this layer 'pool_1'.
# * The fourth layer should be a Flatten layer, named 'flatten'.
# * The fifth layer should be a Dense layer with 32 units, a ReLU activation. Name this layer 'dense_1'.
# * The sixth and final layer should be a Dense layer with 10 units and softmax activation. Name this layer 'dense_2'.
#
# In total, the network should have 6 layers.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_new_model(input_shape):
    
    training_model =  Sequential([
        Conv2D(16,(3,3),activation='relu', padding='SAME',name='conv_1', input_shape=input_shape),
        Conv2D(8,(3,3),activation='relu', padding='SAME',name='conv_2'),
        MaxPooling2D((8,8),name='pool_1'),
        Flatten(name='flatten'),
        Dense(32,activation='relu', name='dense_1'),
        Dense(10,activation='softmax',name='dense_2')
    ])
    
    training_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return training_model
    
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should also compile the model with the Adam optimiser, sparse categorical cross
    entropy loss function, and a single accuracy metric.
    """

# %% [markdown]
# #### Compile and evaluate the model

# %%
# Run your function to create the model
model = get_new_model(x_train[0].shape)

# %%
# Run this cell to define a function to evaluate a model's test accuracy

def get_test_accuracy(model, x_test, y_test):
    """Test model classification accuracy"""
    test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
    print('accuracy: {acc:0.3f}'.format(acc=test_acc))

# %%
# Print the model summary and calculate its initialised test accuracy
model.summary()
get_test_accuracy(model, x_test, y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 64, 64, 8)         1160
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 8, 8, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                16416
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 18,354
# Trainable params: 18,354
# Non-trainable params: 0
# _________________________________________________________________
# accuracy: 0.104

# %% [markdown]
# #### Create checkpoints to save model during training, with a criterion
#
# You will now create three callbacks:
# - `checkpoint_every_epoch`: checkpoint that saves the model weights every epoch during training
# - `checkpoint_best_only`: checkpoint that saves only the weights with the highest validation accuracy. Use the testing data as the validation data.
# - `early_stopping`: early stopping object that ends training if the validation accuracy has not improved in 3 epochs.

# %%
#### GRADED CELL ####
# Complete the following functions. 
# Make sure to not change the function names or arguments.

def get_checkpoint_every_epoch():
    
    checkpoint_path = 'checkpoints_every_epoch/checkpoint_{epoch:03d}'
    checkpoint_epoch =  ModelCheckpoint(filepath=checkpoint_path, frequency='epoch',save_weights_only=True,save_freq=300,verbose=1)
    
    return checkpoint_epoch
    """
    This function should return a ModelCheckpoint object that:
    - saves the weights only at the end of every epoch
    - saves into a directory called 'checkpoints_every_epoch' inside the current working directory
    - generates filenames in that directory like 'checkpoint_XXX' where
      XXX is the epoch number formatted to have three digits, e.g. 001, 002, 003, etc.
    """
def get_checkpoint_best_only():
    
    checkpoint_best_path = 'checkpoints_best_only/checkpoint'
    checkpoint_best= ModelCheckpoint(filepath=checkpoint_best_path,
                                save_weights_only=True,
                                save_freq='epoch',
                                monitor='val_accuracy',
                                save_best_only=True,
                                verbose=1)
    return checkpoint_best
    """
    This function should return a ModelCheckpoint object that:
    - saves only the weights that generate the highest validation (testing) accuracy
    - saves into a directory called 'checkpoints_best_only' inside the current working directory
    - generates a file called 'checkpoints_best_only/checkpoint' 
    """

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_early_stopping():
    
    es = EarlyStopping(monitor='val_accuracy', mode='max',patience=3)
    
    return es
    """
    This function should return an EarlyStopping callback that stops training when
    the validation (testing) accuracy has not improved in the last 3 epochs.
    HINT: use the EarlyStopping callback with the correct 'monitor' and 'patience'
    """

# %%
# Run this cell to create the callbacks

checkpoint_every_epoch = get_checkpoint_every_epoch()
checkpoint_best_only = get_checkpoint_best_only()
early_stopping = get_early_stopping()

# %% [markdown]
# #### Train model using the callbacks
#
# Now, you will train the model using the three callbacks you created. If you created the callbacks correctly, three things should happen:
# - At the end of every epoch, the model weights are saved into a directory called `checkpoints_every_epoch`
# - At the end of every epoch, the model weights are saved into a directory called `checkpoints_best_only` **only** if those weights lead to the highest test accuracy
# - Training stops when the testing accuracy has not improved in three epochs.
#
# You should then have two directories:
# - A directory called `checkpoints_every_epoch` containing filenames that include `checkpoint_001`, `checkpoint_002`, etc with the `001`, `002` corresponding to the epoch
# - A directory called `checkpoints_best_only` containing filenames that include `checkpoint`, which contain only the weights leading to the highest testing accuracy

# %%
# Train model using the callbacks you just created

callbacks = [checkpoint_every_epoch, checkpoint_best_only, early_stopping]
model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=callbacks)
# Out:
# Train on 4000 samples, validate on 1000 samples
# Epoch 1/50
#  288/4000 [=>............................] - ETA: 1:19 - loss: 2.2814 - accuracy: 0.1181
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
#  608/4000 [===>..........................] - ETA: 1:06 - loss: 2.2729 - accuracy: 0.0987
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
#  928/4000 [=====>........................] - ETA: 57s - loss: 2.2523 - accuracy: 0.1196
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 1248/4000 [========>.....................] - ETA: 50s - loss: 2.2318 - accuracy: 0.1266
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 1568/4000 [==========>...................] - ETA: 44s - loss: 2.2037 - accuracy: 0.1339
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 1888/4000 [=============>................] - ETA: 38s - loss: 2.1708 - accuracy: 0.1393
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 2208/4000 [===============>..............] - ETA: 32s - loss: 2.1434 - accuracy: 0.1540
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 2528/4000 [=================>............] - ETA: 26s - loss: 2.1162 - accuracy: 0.1701
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 2848/4000 [====================>.........] - ETA: 20s - loss: 2.0958 - accuracy: 0.1843
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 3168/4000 [======================>.......] - ETA: 14s - loss: 2.0639 - accuracy: 0.2011
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 3488/4000 [=========================>....] - ETA: 9s - loss: 2.0339 - accuracy: 0.2147
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 3808/4000 [===========================>..] - ETA: 3s - loss: 2.0045 - accuracy: 0.2253
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.9954 - accuracy: 0.2311
# Epoch 00001: val_accuracy improved from -inf to 0.37300, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 77s 19ms/sample - loss: 1.9914 - accuracy: 0.2330 - val_loss: 1.5984 - val_accuracy: 0.3730
# Epoch 2/50
#  128/4000 [..............................] - ETA: 1:04 - loss: 1.6339 - accuracy: 0.3203
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
#  448/4000 [==>...........................] - ETA: 1:01 - loss: 1.6007 - accuracy: 0.3214
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
#  768/4000 [====>.........................] - ETA: 56s - loss: 1.5996 - accuracy: 0.3372
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 1088/4000 [=======>......................] - ETA: 50s - loss: 1.5632 - accuracy: 0.3649
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 1408/4000 [=========>....................] - ETA: 44s - loss: 1.5611 - accuracy: 0.3714
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 1728/4000 [===========>..................] - ETA: 39s - loss: 1.5401 - accuracy: 0.3819
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 2048/4000 [==============>...............] - ETA: 33s - loss: 1.5361 - accuracy: 0.3887
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 2368/4000 [================>.............] - ETA: 28s - loss: 1.5319 - accuracy: 0.3923
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 2688/4000 [===================>..........] - ETA: 22s - loss: 1.5325 - accuracy: 0.3921
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 3008/4000 [=====================>........] - ETA: 17s - loss: 1.5228 - accuracy: 0.3916
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 3328/4000 [=======================>......] - ETA: 11s - loss: 1.5134 - accuracy: 0.3975
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 3648/4000 [==========================>...] - ETA: 6s - loss: 1.5080 - accuracy: 0.4035
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.4957 - accuracy: 0.4080
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
#
# Epoch 00002: val_accuracy improved from 0.37300 to 0.41100, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 75s 19ms/sample - loss: 1.4966 - accuracy: 0.4075 - val_loss: 1.5322 - val_accuracy: 0.4110
# Epoch 3/50
#  288/4000 [=>............................] - ETA: 1:03 - loss: 1.4417 - accuracy: 0.4028
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
#  608/4000 [===>..........................] - ETA: 57s - loss: 1.3616 - accuracy: 0.4688
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
#  928/4000 [=====>........................] - ETA: 53s - loss: 1.3690 - accuracy: 0.4644
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 1248/4000 [========>.....................] - ETA: 48s - loss: 1.3698 - accuracy: 0.4679
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 1568/4000 [==========>...................] - ETA: 42s - loss: 1.3673 - accuracy: 0.4636
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 1888/4000 [=============>................] - ETA: 36s - loss: 1.3594 - accuracy: 0.4730
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 2208/4000 [===============>..............] - ETA: 31s - loss: 1.3738 - accuracy: 0.4706
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 2528/4000 [=================>............] - ETA: 25s - loss: 1.3754 - accuracy: 0.4699
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 2848/4000 [====================>.........] - ETA: 20s - loss: 1.3611 - accuracy: 0.4807
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 3168/4000 [======================>.......] - ETA: 14s - loss: 1.3505 - accuracy: 0.4874
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 3488/4000 [=========================>....] - ETA: 9s - loss: 1.3502 - accuracy: 0.4900
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 3808/4000 [===========================>..] - ETA: 3s - loss: 1.3465 - accuracy: 0.4926
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.3428 - accuracy: 0.4955
# Epoch 00003: val_accuracy improved from 0.41100 to 0.49600, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 76s 19ms/sample - loss: 1.3408 - accuracy: 0.4955 - val_loss: 1.2845 - val_accuracy: 0.4960
# Epoch 4/50
#  128/4000 [..............................] - ETA: 1:01 - loss: 1.2375 - accuracy: 0.5000
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
#  448/4000 [==>...........................] - ETA: 1:02 - loss: 1.2903 - accuracy: 0.4821
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
#  768/4000 [====>.........................] - ETA: 56s - loss: 1.2711 - accuracy: 0.5039
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 1088/4000 [=======>......................] - ETA: 50s - loss: 1.2737 - accuracy: 0.5064
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 1408/4000 [=========>....................] - ETA: 45s - loss: 1.2713 - accuracy: 0.5043
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 1728/4000 [===========>..................] - ETA: 40s - loss: 1.2688 - accuracy: 0.5029
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 2048/4000 [==============>...............] - ETA: 34s - loss: 1.2673 - accuracy: 0.5093
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 2368/4000 [================>.............] - ETA: 28s - loss: 1.2632 - accuracy: 0.5165
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 2688/4000 [===================>..........] - ETA: 23s - loss: 1.2566 - accuracy: 0.5171
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 3008/4000 [=====================>........] - ETA: 17s - loss: 1.2525 - accuracy: 0.5189
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 3328/4000 [=======================>......] - ETA: 11s - loss: 1.2606 - accuracy: 0.5186
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 3648/4000 [==========================>...] - ETA: 6s - loss: 1.2617 - accuracy: 0.5186
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.2529 - accuracy: 0.5224
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
#
# Epoch 00004: val_accuracy improved from 0.49600 to 0.53200, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 76s 19ms/sample - loss: 1.2530 - accuracy: 0.5213 - val_loss: 1.2465 - val_accuracy: 0.5320
# Epoch 5/50
#  288/4000 [=>............................] - ETA: 1:02 - loss: 1.2370 - accuracy: 0.5312
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
#  608/4000 [===>..........................] - ETA: 56s - loss: 1.2477 - accuracy: 0.5280
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
#  928/4000 [=====>........................] - ETA: 51s - loss: 1.2494 - accuracy: 0.5183
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 1248/4000 [========>.....................] - ETA: 45s - loss: 1.2341 - accuracy: 0.5264
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 1568/4000 [==========>...................] - ETA: 40s - loss: 1.2425 - accuracy: 0.5261
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 1888/4000 [=============>................] - ETA: 35s - loss: 1.2256 - accuracy: 0.5381
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 2208/4000 [===============>..............] - ETA: 30s - loss: 1.2323 - accuracy: 0.5349
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 2528/4000 [=================>............] - ETA: 24s - loss: 1.2225 - accuracy: 0.5403
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 2848/4000 [====================>.........] - ETA: 19s - loss: 1.2198 - accuracy: 0.5425
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 3168/4000 [======================>.......] - ETA: 14s - loss: 1.2140 - accuracy: 0.5423
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 3488/4000 [=========================>....] - ETA: 8s - loss: 1.2090 - accuracy: 0.5490
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 3808/4000 [===========================>..] - ETA: 3s - loss: 1.2102 - accuracy: 0.5475
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.2086 - accuracy: 0.5474
# Epoch 00005: val_accuracy improved from 0.53200 to 0.56700, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 73s 18ms/sample - loss: 1.2073 - accuracy: 0.5475 - val_loss: 1.1647 - val_accuracy: 0.5670
# Epoch 6/50
#  128/4000 [..............................] - ETA: 1:04 - loss: 1.0236 - accuracy: 0.6484
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
#  448/4000 [==>...........................] - ETA: 58s - loss: 1.0790 - accuracy: 0.5982
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
#  768/4000 [====>.........................] - ETA: 53s - loss: 1.1046 - accuracy: 0.5833
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 1088/4000 [=======>......................] - ETA: 48s - loss: 1.1331 - accuracy: 0.5726
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 1408/4000 [=========>....................] - ETA: 42s - loss: 1.1386 - accuracy: 0.5781
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 1728/4000 [===========>..................] - ETA: 37s - loss: 1.1576 - accuracy: 0.5758
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 2048/4000 [==============>...............] - ETA: 32s - loss: 1.1467 - accuracy: 0.5781
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 2368/4000 [================>.............] - ETA: 27s - loss: 1.1308 - accuracy: 0.5828
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 2688/4000 [===================>..........] - ETA: 21s - loss: 1.1379 - accuracy: 0.5774
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 3008/4000 [=====================>........] - ETA: 16s - loss: 1.1345 - accuracy: 0.5814
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 3328/4000 [=======================>......] - ETA: 11s - loss: 1.1300 - accuracy: 0.5817
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 3648/4000 [==========================>...] - ETA: 5s - loss: 1.1247 - accuracy: 0.5811
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.1241 - accuracy: 0.5811
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
#
# Epoch 00006: val_accuracy did not improve from 0.56700
# 4000/4000 [==============================] - 73s 18ms/sample - loss: 1.1218 - accuracy: 0.5820 - val_loss: 1.1983 - val_accuracy: 0.5240
# Epoch 7/50
#  288/4000 [=>............................] - ETA: 1:06 - loss: 1.0662 - accuracy: 0.6076
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
#  608/4000 [===>..........................] - ETA: 59s - loss: 1.0914 - accuracy: 0.5822
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
#  928/4000 [=====>........................] - ETA: 53s - loss: 1.0842 - accuracy: 0.5916
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 1248/4000 [========>.....................] - ETA: 47s - loss: 1.0681 - accuracy: 0.5978
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 1568/4000 [==========>...................] - ETA: 42s - loss: 1.0594 - accuracy: 0.5976
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 1888/4000 [=============>................] - ETA: 37s - loss: 1.0644 - accuracy: 0.5969
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 2208/4000 [===============>..............] - ETA: 31s - loss: 1.0653 - accuracy: 0.5978
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 2528/4000 [=================>............] - ETA: 25s - loss: 1.0918 - accuracy: 0.5910
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 2848/4000 [====================>.........] - ETA: 20s - loss: 1.0941 - accuracy: 0.5920
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 3168/4000 [======================>.......] - ETA: 14s - loss: 1.0916 - accuracy: 0.5956
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 3488/4000 [=========================>....] - ETA: 9s - loss: 1.0886 - accuracy: 0.5978
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 3808/4000 [===========================>..] - ETA: 3s - loss: 1.0853 - accuracy: 0.5980
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.0847 - accuracy: 0.5980
# Epoch 00007: val_accuracy improved from 0.56700 to 0.58600, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 77s 19ms/sample - loss: 1.0845 - accuracy: 0.5982 - val_loss: 1.1096 - val_accuracy: 0.5860
# Epoch 8/50
#  128/4000 [..............................] - ETA: 1:09 - loss: 1.1402 - accuracy: 0.5781
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
#  448/4000 [==>...........................] - ETA: 1:05 - loss: 1.1259 - accuracy: 0.5915
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
#  768/4000 [====>.........................] - ETA: 58s - loss: 1.1089 - accuracy: 0.5898
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 1088/4000 [=======>......................] - ETA: 52s - loss: 1.0635 - accuracy: 0.5965
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 1408/4000 [=========>....................] - ETA: 47s - loss: 1.0578 - accuracy: 0.5994
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 1728/4000 [===========>..................] - ETA: 41s - loss: 1.0658 - accuracy: 0.6001
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 2048/4000 [==============>...............] - ETA: 35s - loss: 1.0629 - accuracy: 0.6006
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 2368/4000 [================>.............] - ETA: 29s - loss: 1.0661 - accuracy: 0.5992
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 2688/4000 [===================>..........] - ETA: 23s - loss: 1.0591 - accuracy: 0.6045
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 3008/4000 [=====================>........] - ETA: 17s - loss: 1.0558 - accuracy: 0.6031
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 3328/4000 [=======================>......] - ETA: 12s - loss: 1.0502 - accuracy: 0.6049
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 3648/4000 [==========================>...] - ETA: 6s - loss: 1.0481 - accuracy: 0.6088
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.0435 - accuracy: 0.6089
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
#
# Epoch 00008: val_accuracy improved from 0.58600 to 0.59400, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 78s 19ms/sample - loss: 1.0461 - accuracy: 0.6070 - val_loss: 1.0852 - val_accuracy: 0.5940
# Epoch 9/50
#  288/4000 [=>............................] - ETA: 1:07 - loss: 0.9649 - accuracy: 0.6562
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
#  608/4000 [===>..........................] - ETA: 1:01 - loss: 1.0657 - accuracy: 0.6168
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
#  928/4000 [=====>........................] - ETA: 55s - loss: 1.0421 - accuracy: 0.6228
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 1248/4000 [========>.....................] - ETA: 50s - loss: 1.0367 - accuracy: 0.6202
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 1568/4000 [==========>...................] - ETA: 44s - loss: 1.0194 - accuracy: 0.6224
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 1888/4000 [=============>................] - ETA: 38s - loss: 1.0098 - accuracy: 0.6303
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 2208/4000 [===============>..............] - ETA: 32s - loss: 1.0202 - accuracy: 0.6227
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 2528/4000 [=================>............] - ETA: 26s - loss: 1.0226 - accuracy: 0.6250
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 2848/4000 [====================>.........] - ETA: 21s - loss: 1.0177 - accuracy: 0.6264
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 3168/4000 [======================>.......] - ETA: 15s - loss: 1.0094 - accuracy: 0.6266
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 3488/4000 [=========================>....] - ETA: 9s - loss: 1.0095 - accuracy: 0.6244
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 3808/4000 [===========================>..] - ETA: 3s - loss: 1.0051 - accuracy: 0.6242
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.0024 - accuracy: 0.6265
# Epoch 00009: val_accuracy did not improve from 0.59400
# 4000/4000 [==============================] - 79s 20ms/sample - loss: 1.0012 - accuracy: 0.6267 - val_loss: 1.0985 - val_accuracy: 0.5820
# Epoch 10/50
#  128/4000 [..............................] - ETA: 1:06 - loss: 1.0825 - accuracy: 0.5703
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
#  448/4000 [==>...........................] - ETA: 1:03 - loss: 0.9666 - accuracy: 0.6540
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
#  768/4000 [====>.........................] - ETA: 58s - loss: 0.9785 - accuracy: 0.6419
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 1088/4000 [=======>......................] - ETA: 53s - loss: 0.9478 - accuracy: 0.6562
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 1408/4000 [=========>....................] - ETA: 47s - loss: 0.9841 - accuracy: 0.6413
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 1728/4000 [===========>..................] - ETA: 41s - loss: 1.0005 - accuracy: 0.6291
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 2048/4000 [==============>...............] - ETA: 35s - loss: 1.0027 - accuracy: 0.6274
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 2368/4000 [================>.............] - ETA: 29s - loss: 0.9997 - accuracy: 0.6322
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 2688/4000 [===================>..........] - ETA: 23s - loss: 1.0029 - accuracy: 0.6287
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 3008/4000 [=====================>........] - ETA: 18s - loss: 0.9935 - accuracy: 0.6336
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 3328/4000 [=======================>......] - ETA: 12s - loss: 0.9957 - accuracy: 0.6325
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 3648/4000 [==========================>...] - ETA: 6s - loss: 0.9986 - accuracy: 0.6299
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9994 - accuracy: 0.6260
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
#
# Epoch 00010: val_accuracy did not improve from 0.59400
# 4000/4000 [==============================] - 78s 20ms/sample - loss: 0.9995 - accuracy: 0.6267 - val_loss: 1.1803 - val_accuracy: 0.5660
# Epoch 11/50
#  288/4000 [=>............................] - ETA: 1:05 - loss: 1.0598 - accuracy: 0.6250
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
#  608/4000 [===>..........................] - ETA: 59s - loss: 1.0015 - accuracy: 0.6316
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
#  928/4000 [=====>........................] - ETA: 54s - loss: 0.9627 - accuracy: 0.6379
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 1248/4000 [========>.....................] - ETA: 48s - loss: 0.9689 - accuracy: 0.6322
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 1568/4000 [==========>...................] - ETA: 42s - loss: 0.9617 - accuracy: 0.6371
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 1888/4000 [=============>................] - ETA: 36s - loss: 0.9542 - accuracy: 0.6435
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 2208/4000 [===============>..............] - ETA: 31s - loss: 0.9392 - accuracy: 0.6499
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 2528/4000 [=================>............] - ETA: 25s - loss: 0.9460 - accuracy: 0.6511
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 2848/4000 [====================>.........] - ETA: 19s - loss: 0.9477 - accuracy: 0.6527
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 3168/4000 [======================>.......] - ETA: 14s - loss: 0.9545 - accuracy: 0.6499
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 3488/4000 [=========================>....] - ETA: 8s - loss: 0.9500 - accuracy: 0.6505
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 3808/4000 [===========================>..] - ETA: 3s - loss: 0.9498 - accuracy: 0.6494
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9482 - accuracy: 0.6492
# Epoch 00011: val_accuracy improved from 0.59400 to 0.61600, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 73s 18ms/sample - loss: 0.9474 - accuracy: 0.6492 - val_loss: 1.0750 - val_accuracy: 0.6160
# Epoch 12/50
#  128/4000 [..............................] - ETA: 1:04 - loss: 0.9276 - accuracy: 0.7188
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
#  448/4000 [==>...........................] - ETA: 59s - loss: 0.9161 - accuracy: 0.6830
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
#  768/4000 [====>.........................] - ETA: 54s - loss: 0.9092 - accuracy: 0.6745
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 1088/4000 [=======>......................] - ETA: 49s - loss: 0.9131 - accuracy: 0.6636
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 1408/4000 [=========>....................] - ETA: 43s - loss: 0.9098 - accuracy: 0.6634
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 1728/4000 [===========>..................] - ETA: 38s - loss: 0.9298 - accuracy: 0.6551
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 2048/4000 [==============>...............] - ETA: 33s - loss: 0.9291 - accuracy: 0.6519
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 2368/4000 [================>.............] - ETA: 27s - loss: 0.9181 - accuracy: 0.6579
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 2688/4000 [===================>..........] - ETA: 22s - loss: 0.9165 - accuracy: 0.6559
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 3008/4000 [=====================>........] - ETA: 16s - loss: 0.9128 - accuracy: 0.6572
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 3328/4000 [=======================>......] - ETA: 11s - loss: 0.9122 - accuracy: 0.6553
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 3648/4000 [==========================>...] - ETA: 5s - loss: 0.9100 - accuracy: 0.6579
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9075 - accuracy: 0.6600
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
#
# Epoch 00012: val_accuracy improved from 0.61600 to 0.64600, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 74s 18ms/sample - loss: 0.9093 - accuracy: 0.6603 - val_loss: 1.0375 - val_accuracy: 0.6460
# Epoch 13/50
#  288/4000 [=>............................] - ETA: 1:02 - loss: 0.9372 - accuracy: 0.6875
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
#  608/4000 [===>..........................] - ETA: 58s - loss: 0.8939 - accuracy: 0.6694
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
#  928/4000 [=====>........................] - ETA: 53s - loss: 0.9094 - accuracy: 0.6616
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 1248/4000 [========>.....................] - ETA: 48s - loss: 0.9137 - accuracy: 0.6667
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 1568/4000 [==========>...................] - ETA: 42s - loss: 0.9255 - accuracy: 0.6569
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 1888/4000 [=============>................] - ETA: 36s - loss: 0.9265 - accuracy: 0.6605
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 2208/4000 [===============>..............] - ETA: 31s - loss: 0.9123 - accuracy: 0.6680
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 2528/4000 [=================>............] - ETA: 25s - loss: 0.8988 - accuracy: 0.6717
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 2848/4000 [====================>.........] - ETA: 20s - loss: 0.8996 - accuracy: 0.6699
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 3168/4000 [======================>.......] - ETA: 14s - loss: 0.9075 - accuracy: 0.6641
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 3488/4000 [=========================>....] - ETA: 8s - loss: 0.9005 - accuracy: 0.6674
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 3808/4000 [===========================>..] - ETA: 3s - loss: 0.8980 - accuracy: 0.6696
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8937 - accuracy: 0.6711
# Epoch 00013: val_accuracy did not improve from 0.64600
# 4000/4000 [==============================] - 75s 19ms/sample - loss: 0.8933 - accuracy: 0.6708 - val_loss: 0.9617 - val_accuracy: 0.6440
# Epoch 14/50
#  128/4000 [..............................] - ETA: 1:03 - loss: 0.8878 - accuracy: 0.6406
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
#  448/4000 [==>...........................] - ETA: 1:03 - loss: 0.8138 - accuracy: 0.7054
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
#  768/4000 [====>.........................] - ETA: 56s - loss: 0.8229 - accuracy: 0.7135
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 1088/4000 [=======>......................] - ETA: 51s - loss: 0.8382 - accuracy: 0.7013
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 1408/4000 [=========>....................] - ETA: 45s - loss: 0.8362 - accuracy: 0.6982
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 1728/4000 [===========>..................] - ETA: 39s - loss: 0.8388 - accuracy: 0.6944
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 2048/4000 [==============>...............] - ETA: 34s - loss: 0.8300 - accuracy: 0.6982
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 2368/4000 [================>.............] - ETA: 28s - loss: 0.8313 - accuracy: 0.6989
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 2688/4000 [===================>..........] - ETA: 22s - loss: 0.8429 - accuracy: 0.6931
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 3008/4000 [=====================>........] - ETA: 17s - loss: 0.8473 - accuracy: 0.6948
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 3328/4000 [=======================>......] - ETA: 11s - loss: 0.8492 - accuracy: 0.6932
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 3648/4000 [==========================>...] - ETA: 6s - loss: 0.8426 - accuracy: 0.6979
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8430 - accuracy: 0.6953
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
#
# Epoch 00014: val_accuracy improved from 0.64600 to 0.66400, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 76s 19ms/sample - loss: 0.8421 - accuracy: 0.6955 - val_loss: 0.9273 - val_accuracy: 0.6640
# Epoch 15/50
#  288/4000 [=>............................] - ETA: 1:03 - loss: 0.8635 - accuracy: 0.6528
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
#  608/4000 [===>..........................] - ETA: 58s - loss: 0.8633 - accuracy: 0.6595
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
#  928/4000 [=====>........................] - ETA: 53s - loss: 0.8401 - accuracy: 0.6746
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 1248/4000 [========>.....................] - ETA: 47s - loss: 0.8366 - accuracy: 0.6867
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 1568/4000 [==========>...................] - ETA: 42s - loss: 0.8516 - accuracy: 0.6792
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 1888/4000 [=============>................] - ETA: 36s - loss: 0.8395 - accuracy: 0.6912
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 2208/4000 [===============>..............] - ETA: 31s - loss: 0.8396 - accuracy: 0.6907
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 2528/4000 [=================>............] - ETA: 25s - loss: 0.8300 - accuracy: 0.6926
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 2848/4000 [====================>.........] - ETA: 20s - loss: 0.8320 - accuracy: 0.6917
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 3168/4000 [======================>.......] - ETA: 14s - loss: 0.8370 - accuracy: 0.6916
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 3488/4000 [=========================>....] - ETA: 8s - loss: 0.8383 - accuracy: 0.6929
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 3808/4000 [===========================>..] - ETA: 3s - loss: 0.8327 - accuracy: 0.6956
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8323 - accuracy: 0.6963
# Epoch 00015: val_accuracy improved from 0.66400 to 0.68900, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 75s 19ms/sample - loss: 0.8339 - accuracy: 0.6957 - val_loss: 0.8792 - val_accuracy: 0.6890
# Epoch 16/50
#  128/4000 [..............................] - ETA: 1:09 - loss: 0.7649 - accuracy: 0.7031
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
#  448/4000 [==>...........................] - ETA: 1:02 - loss: 0.8033 - accuracy: 0.6853
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
#  768/4000 [====>.........................] - ETA: 57s - loss: 0.8127 - accuracy: 0.6979
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 1088/4000 [=======>......................] - ETA: 51s - loss: 0.8058 - accuracy: 0.7086
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 1408/4000 [=========>....................] - ETA: 45s - loss: 0.8069 - accuracy: 0.7024
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 1728/4000 [===========>..................] - ETA: 39s - loss: 0.7999 - accuracy: 0.7060
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 2048/4000 [==============>...............] - ETA: 34s - loss: 0.8018 - accuracy: 0.7085
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 2368/4000 [================>.............] - ETA: 28s - loss: 0.8132 - accuracy: 0.7065
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 2688/4000 [===================>..........] - ETA: 22s - loss: 0.8138 - accuracy: 0.7050
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 3008/4000 [=====================>........] - ETA: 17s - loss: 0.8095 - accuracy: 0.7084
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 3328/4000 [=======================>......] - ETA: 11s - loss: 0.8060 - accuracy: 0.7091
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 3648/4000 [==========================>...] - ETA: 6s - loss: 0.7988 - accuracy: 0.7094
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7988 - accuracy: 0.7064
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
#
# Epoch 00016: val_accuracy improved from 0.68900 to 0.69900, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 76s 19ms/sample - loss: 0.7967 - accuracy: 0.7078 - val_loss: 0.8517 - val_accuracy: 0.6990
# Epoch 17/50
#  288/4000 [=>............................] - ETA: 1:02 - loss: 0.6822 - accuracy: 0.7986
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
#  608/4000 [===>..........................] - ETA: 58s - loss: 0.7432 - accuracy: 0.7582
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
#  928/4000 [=====>........................] - ETA: 52s - loss: 0.7640 - accuracy: 0.7274
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 1248/4000 [========>.....................] - ETA: 47s - loss: 0.7640 - accuracy: 0.7244
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 1568/4000 [==========>...................] - ETA: 41s - loss: 0.7726 - accuracy: 0.7156
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 1888/4000 [=============>................] - ETA: 36s - loss: 0.7885 - accuracy: 0.7129
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 2208/4000 [===============>..............] - ETA: 30s - loss: 0.7885 - accuracy: 0.7111
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 2528/4000 [=================>............] - ETA: 25s - loss: 0.7894 - accuracy: 0.7124
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 2848/4000 [====================>.........] - ETA: 19s - loss: 0.7768 - accuracy: 0.7163
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 3168/4000 [======================>.......] - ETA: 14s - loss: 0.7718 - accuracy: 0.7210
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 3488/4000 [=========================>....] - ETA: 8s - loss: 0.7666 - accuracy: 0.7253
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 3808/4000 [===========================>..] - ETA: 3s - loss: 0.7706 - accuracy: 0.7219
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7736 - accuracy: 0.7205
# Epoch 00017: val_accuracy did not improve from 0.69900
# 4000/4000 [==============================] - 75s 19ms/sample - loss: 0.7731 - accuracy: 0.7210 - val_loss: 0.9107 - val_accuracy: 0.6860
# Epoch 18/50
#  128/4000 [..............................] - ETA: 1:03 - loss: 0.7555 - accuracy: 0.7031
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
#  448/4000 [==>...........................] - ETA: 1:00 - loss: 0.8094 - accuracy: 0.6964
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
#  768/4000 [====>.........................] - ETA: 55s - loss: 0.7848 - accuracy: 0.7135
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 1088/4000 [=======>......................] - ETA: 49s - loss: 0.7676 - accuracy: 0.7243
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 1408/4000 [=========>....................] - ETA: 44s - loss: 0.7689 - accuracy: 0.7223
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 1728/4000 [===========>..................] - ETA: 38s - loss: 0.7725 - accuracy: 0.7205
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 2048/4000 [==============>...............] - ETA: 33s - loss: 0.7540 - accuracy: 0.7334
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 2368/4000 [================>.............] - ETA: 27s - loss: 0.7655 - accuracy: 0.7280
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 2688/4000 [===================>..........] - ETA: 22s - loss: 0.7701 - accuracy: 0.7262
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 3008/4000 [=====================>........] - ETA: 17s - loss: 0.7600 - accuracy: 0.7271
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 3328/4000 [=======================>......] - ETA: 11s - loss: 0.7667 - accuracy: 0.7239
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 3648/4000 [==========================>...] - ETA: 6s - loss: 0.7636 - accuracy: 0.7245
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7562 - accuracy: 0.7276
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
#
# Epoch 00018: val_accuracy improved from 0.69900 to 0.71000, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 74s 19ms/sample - loss: 0.7530 - accuracy: 0.7293 - val_loss: 0.8191 - val_accuracy: 0.7100
# Epoch 19/50
#  288/4000 [=>............................] - ETA: 1:03 - loss: 0.6690 - accuracy: 0.7708
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
#  608/4000 [===>..........................] - ETA: 59s - loss: 0.6874 - accuracy: 0.7484
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
#  928/4000 [=====>........................] - ETA: 54s - loss: 0.7057 - accuracy: 0.7478
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 1248/4000 [========>.....................] - ETA: 48s - loss: 0.7233 - accuracy: 0.7436
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 1568/4000 [==========>...................] - ETA: 42s - loss: 0.7264 - accuracy: 0.7411
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 1888/4000 [=============>................] - ETA: 37s - loss: 0.7272 - accuracy: 0.7415
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 2208/4000 [===============>..............] - ETA: 31s - loss: 0.7206 - accuracy: 0.7414
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 2528/4000 [=================>............] - ETA: 25s - loss: 0.7274 - accuracy: 0.7354
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 2848/4000 [====================>.........] - ETA: 20s - loss: 0.7315 - accuracy: 0.7342
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 3168/4000 [======================>.......] - ETA: 14s - loss: 0.7276 - accuracy: 0.7358
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 3488/4000 [=========================>....] - ETA: 8s - loss: 0.7336 - accuracy: 0.7317
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 3808/4000 [===========================>..] - ETA: 3s - loss: 0.7319 - accuracy: 0.7340
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7280 - accuracy: 0.7359
# Epoch 00019: val_accuracy did not improve from 0.71000
# 4000/4000 [==============================] - 75s 19ms/sample - loss: 0.7307 - accuracy: 0.7355 - val_loss: 0.8312 - val_accuracy: 0.7040
# Epoch 20/50
#  128/4000 [..............................] - ETA: 1:06 - loss: 0.6430 - accuracy: 0.8125
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
#  448/4000 [==>...........................] - ETA: 1:03 - loss: 0.6911 - accuracy: 0.7589
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
#  768/4000 [====>.........................] - ETA: 57s - loss: 0.7140 - accuracy: 0.7435
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 1088/4000 [=======>......................] - ETA: 51s - loss: 0.7088 - accuracy: 0.7491
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 1408/4000 [=========>....................] - ETA: 46s - loss: 0.7170 - accuracy: 0.7514
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 1728/4000 [===========>..................] - ETA: 40s - loss: 0.7166 - accuracy: 0.7488
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 2048/4000 [==============>...............] - ETA: 34s - loss: 0.7134 - accuracy: 0.7505
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 2368/4000 [================>.............] - ETA: 28s - loss: 0.7149 - accuracy: 0.7492
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 2688/4000 [===================>..........] - ETA: 23s - loss: 0.7132 - accuracy: 0.7467
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 3008/4000 [=====================>........] - ETA: 17s - loss: 0.7130 - accuracy: 0.7470
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 3328/4000 [=======================>......] - ETA: 11s - loss: 0.7054 - accuracy: 0.7503
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 3648/4000 [==========================>...] - ETA: 6s - loss: 0.7061 - accuracy: 0.7508
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.7505
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
#
# Epoch 00020: val_accuracy improved from 0.71000 to 0.71100, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 76s 19ms/sample - loss: 0.7068 - accuracy: 0.7502 - val_loss: 0.8311 - val_accuracy: 0.7110
# Epoch 21/50
#  288/4000 [=>............................] - ETA: 1:03 - loss: 0.6482 - accuracy: 0.7639
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
#  608/4000 [===>..........................] - ETA: 57s - loss: 0.7057 - accuracy: 0.7467
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
#  928/4000 [=====>........................] - ETA: 53s - loss: 0.7273 - accuracy: 0.7274
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 1248/4000 [========>.....................] - ETA: 47s - loss: 0.6916 - accuracy: 0.7412
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 1568/4000 [==========>...................] - ETA: 42s - loss: 0.6935 - accuracy: 0.7449
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 1888/4000 [=============>................] - ETA: 36s - loss: 0.6899 - accuracy: 0.7500
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 2208/4000 [===============>..............] - ETA: 31s - loss: 0.6885 - accuracy: 0.7514
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 2528/4000 [=================>............] - ETA: 25s - loss: 0.6981 - accuracy: 0.7488
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 2848/4000 [====================>.........] - ETA: 19s - loss: 0.7020 - accuracy: 0.7451
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 3168/4000 [======================>.......] - ETA: 14s - loss: 0.7007 - accuracy: 0.7456
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 3488/4000 [=========================>....] - ETA: 8s - loss: 0.7070 - accuracy: 0.7437
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 3808/4000 [===========================>..] - ETA: 3s - loss: 0.7042 - accuracy: 0.7429
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7044 - accuracy: 0.7422
# Epoch 00021: val_accuracy improved from 0.71100 to 0.71500, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 75s 19ms/sample - loss: 0.7025 - accuracy: 0.7433 - val_loss: 0.8211 - val_accuracy: 0.7150
# Epoch 22/50
#  128/4000 [..............................] - ETA: 1:05 - loss: 0.7300 - accuracy: 0.7500
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
#  448/4000 [==>...........................] - ETA: 59s - loss: 0.6667 - accuracy: 0.7634
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
#  768/4000 [====>.........................] - ETA: 55s - loss: 0.6520 - accuracy: 0.7708
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 1088/4000 [=======>......................] - ETA: 49s - loss: 0.6472 - accuracy: 0.7638
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 1408/4000 [=========>....................] - ETA: 43s - loss: 0.6466 - accuracy: 0.7670
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 1728/4000 [===========>..................] - ETA: 38s - loss: 0.6578 - accuracy: 0.7627
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 2048/4000 [==============>...............] - ETA: 33s - loss: 0.6650 - accuracy: 0.7588
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 2368/4000 [================>.............] - ETA: 27s - loss: 0.6639 - accuracy: 0.7589
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 2688/4000 [===================>..........] - ETA: 22s - loss: 0.6707 - accuracy: 0.7589
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 3008/4000 [=====================>........] - ETA: 16s - loss: 0.6707 - accuracy: 0.7593
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 3328/4000 [=======================>......] - ETA: 11s - loss: 0.6645 - accuracy: 0.7614
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 3648/4000 [==========================>...] - ETA: 6s - loss: 0.6690 - accuracy: 0.7593
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6666 - accuracy: 0.7598
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
#
# Epoch 00022: val_accuracy improved from 0.71500 to 0.71800, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 75s 19ms/sample - loss: 0.6676 - accuracy: 0.7598 - val_loss: 0.8296 - val_accuracy: 0.7180
# Epoch 23/50
#  288/4000 [=>............................] - ETA: 1:03 - loss: 0.6575 - accuracy: 0.7535
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
#  608/4000 [===>..........................] - ETA: 58s - loss: 0.6335 - accuracy: 0.7780
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
#  928/4000 [=====>........................] - ETA: 52s - loss: 0.6442 - accuracy: 0.7823
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 1248/4000 [========>.....................] - ETA: 47s - loss: 0.6410 - accuracy: 0.7780
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 1568/4000 [==========>...................] - ETA: 42s - loss: 0.6655 - accuracy: 0.7666
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 1888/4000 [=============>................] - ETA: 36s - loss: 0.6588 - accuracy: 0.7648
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 2208/4000 [===============>..............] - ETA: 31s - loss: 0.6645 - accuracy: 0.7600
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 2528/4000 [=================>............] - ETA: 25s - loss: 0.6673 - accuracy: 0.7599
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 2848/4000 [====================>.........] - ETA: 19s - loss: 0.6698 - accuracy: 0.7612
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 3168/4000 [======================>.......] - ETA: 14s - loss: 0.6590 - accuracy: 0.7658
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 3488/4000 [=========================>....] - ETA: 8s - loss: 0.6543 - accuracy: 0.7658
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 3808/4000 [===========================>..] - ETA: 3s - loss: 0.6528 - accuracy: 0.7665
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6552 - accuracy: 0.7659
# Epoch 00023: val_accuracy did not improve from 0.71800
# 4000/4000 [==============================] - 75s 19ms/sample - loss: 0.6556 - accuracy: 0.7657 - val_loss: 0.7840 - val_accuracy: 0.7170
# Epoch 24/50
#  128/4000 [..............................] - ETA: 1:06 - loss: 0.6550 - accuracy: 0.7812
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
#  448/4000 [==>...........................] - ETA: 1:01 - loss: 0.6809 - accuracy: 0.7411
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
#  768/4000 [====>.........................] - ETA: 56s - loss: 0.7084 - accuracy: 0.7383
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 1088/4000 [=======>......................] - ETA: 51s - loss: 0.6944 - accuracy: 0.7426
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 1408/4000 [=========>....................] - ETA: 45s - loss: 0.6753 - accuracy: 0.7500
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 1728/4000 [===========>..................] - ETA: 39s - loss: 0.6785 - accuracy: 0.7512
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 2048/4000 [==============>...............] - ETA: 34s - loss: 0.6647 - accuracy: 0.7563
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 2368/4000 [================>.............] - ETA: 28s - loss: 0.6531 - accuracy: 0.7631
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 2688/4000 [===================>..........] - ETA: 23s - loss: 0.6511 - accuracy: 0.7679
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 3008/4000 [=====================>........] - ETA: 17s - loss: 0.6506 - accuracy: 0.7666
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 3328/4000 [=======================>......] - ETA: 11s - loss: 0.6546 - accuracy: 0.7608
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 3648/4000 [==========================>...] - ETA: 6s - loss: 0.6521 - accuracy: 0.7618
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6449 - accuracy: 0.7646
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
#
# Epoch 00024: val_accuracy did not improve from 0.71800
# 4000/4000 [==============================] - 76s 19ms/sample - loss: 0.6445 - accuracy: 0.7648 - val_loss: 0.7668 - val_accuracy: 0.7120
# Epoch 25/50
#  288/4000 [=>............................] - ETA: 1:03 - loss: 0.7290 - accuracy: 0.7153
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
#  608/4000 [===>..........................] - ETA: 59s - loss: 0.7232 - accuracy: 0.7451
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
#  928/4000 [=====>........................] - ETA: 53s - loss: 0.7054 - accuracy: 0.7532
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 1248/4000 [========>.....................] - ETA: 48s - loss: 0.6848 - accuracy: 0.7588
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 1568/4000 [==========>...................] - ETA: 42s - loss: 0.6502 - accuracy: 0.7704
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 1888/4000 [=============>................] - ETA: 37s - loss: 0.6270 - accuracy: 0.7717
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 2208/4000 [===============>..............] - ETA: 31s - loss: 0.6296 - accuracy: 0.7726
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 2528/4000 [=================>............] - ETA: 25s - loss: 0.6365 - accuracy: 0.7698
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 2848/4000 [====================>.........] - ETA: 20s - loss: 0.6294 - accuracy: 0.7707
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 3168/4000 [======================>.......] - ETA: 14s - loss: 0.6238 - accuracy: 0.7724
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 3488/4000 [=========================>....] - ETA: 8s - loss: 0.6191 - accuracy: 0.7761
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 3808/4000 [===========================>..] - ETA: 3s - loss: 0.6237 - accuracy: 0.7755
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6254 - accuracy: 0.7752
# Epoch 00025: val_accuracy did not improve from 0.71800
# 4000/4000 [==============================] - 75s 19ms/sample - loss: 0.6245 - accuracy: 0.7760 - val_loss: 0.7797 - val_accuracy: 0.7140

# %% [markdown]
# #### Create new instance of model and load on both sets of weights
#
# Now you will use the weights you just saved in a fresh model. You should create two functions, both of which take a freshly instantiated model instance:
# - `model_last_epoch` should contain the weights from the latest saved epoch
# - `model_best_epoch` should contain the weights from the saved epoch with the highest testing accuracy
#
# _Hint: use the_ `tf.train.latest_checkpoint` _function to get the filename of the latest saved checkpoint file. Check the docs_ [_here_](https://www.tensorflow.org/api_docs/python/tf/train/latest_checkpoint).

# %%
#### GRADED CELL ####

# Complete the following functions. 
# Make sure to not change the function name or arguments.

def get_model_last_epoch(model):
    
    filepath = tf.train.latest_checkpoint('checkpoints_every_epoch')
    model.load_weights(filepath)
    
    return model
    """
    This function should create a new instance of the CNN you created earlier,
    load on the weights from the last training epoch, and return this model.
    """    
    
def get_model_best_epoch(model):
    
    filepath = tf.train.latest_checkpoint('checkpoints_best_only')
    model.load_weights(filepath)
    
    return model
    
    """
    This function should create a new instance of the CNN you created earlier, load 
    on the weights leading to the highest validation accuracy, and return this model.
    """

# %%
# Run this cell to create two models: one with the weights from the last training
# epoch, and one with the weights leading to the highest validation (testing) accuracy.
# Verify that the second has a higher validation (testing) accuarcy.

model_last_epoch = get_model_last_epoch(get_new_model(x_train[0].shape))
model_best_epoch = get_model_best_epoch(get_new_model(x_train[0].shape))
print('Model with last epoch weights:')
get_test_accuracy(model_last_epoch, x_test, y_test)
print('')
print('Model with best epoch weights:')
get_test_accuracy(model_best_epoch, x_test, y_test)
# Out:
# Model with last epoch weights:
# accuracy: 0.717
#
# Model with best epoch weights:
# accuracy: 0.718

# %% [markdown]
# #### Load, from scratch, a model trained on the EuroSat dataset.
#
# In your workspace, you will find another model trained on the `EuroSAT` dataset in `.h5` format. This model is trained on a larger subset of the EuroSAT dataset and has a more complex architecture. The path to the model is `models/EuroSatNet.h5`. See how its testing accuracy compares to your model!

# %%
#### GRADED CELL ####
import tensorflow_hub as hub

# Complete the following functions. 
# Make sure to not change the function name or arguments.

def get_model_eurosatnet():
    """
    This function should return the pretrained EuroSatNet.h5 model.
    """
    model = load_model('models/EuroSatNet.h5')
    return model

# %%
# Run this cell to print a summary of the EuroSatNet model, along with its validation accuracy.

model_eurosatnet = get_model_eurosatnet()
model_eurosatnet.summary()
get_test_accuracy(model_eurosatnet, x_test, y_test)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 64, 64, 16)        6416
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 32, 32, 16)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 32, 32, 16)        2320
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 32, 32, 16)        6416
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 16, 16, 16)        0
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv_6 (Conv2D)              (None, 16, 16, 16)        6416
# _________________________________________________________________
# pool_3 (MaxPooling2D)        (None, 8, 8, 16)          0
# _________________________________________________________________
# conv_7 (Conv2D)              (None, 8, 8, 16)          2320
# _________________________________________________________________
# conv_8 (Conv2D)              (None, 8, 8, 16)          6416
# _________________________________________________________________
# pool_4 (MaxPooling2D)        (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 41,626
# Trainable params: 41,626
# Non-trainable params: 0
# _________________________________________________________________
# accuracy: 0.810

# %% [markdown]
# Congratulations for completing this programming assignment! You're now ready to move on to the capstone project for this course.
